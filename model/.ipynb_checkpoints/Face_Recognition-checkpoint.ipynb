# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os
from os import listdir
from PIL import Image

"""   
for filename in listdir('./Dataset/Cristiano Ronaldo'):

    if filename.endswith('.png'):
    try:
        img = Image.open('./'+filename) # open the image file
        img.verify() # verify that it is, in fact an image
    except (IOError, SyntaxError) as e:
        location = "./Dataset/Cristiano Ronaldo"
        path = os.path.join(location, filename)
        os.remove(path)
"""
        #print('Bad file:', filename) # print out the names of corrupt files
# Out:
# '   \nfor filename in listdir(\'./Dataset/Cristiano Ronaldo\'):\n\n    if filename.endswith(\'.png\'):\n    try:\n        img = Image.open(\'./\'+filename) # open the image file\n        img.verify() # verify that it is, in fact an image\n    except (IOError, SyntaxError) as e:\n        location = "./Dataset/Cristiano Ronaldo"\n        path = os.path.join(location, filename)\n        os.remove(path)\n'

# %%
img = cv2.imread('./test_images/robert-downey-jr--2.jpg')
img.shape
# Out:
# (750, 900, 3)

# %%
#plotting test image
plt.imshow(img)

# %%
#converting into gray image
grayimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
grayimg.shape
print(grayimg)
# Out:
# [[170 171 174 ... 100  98  98]
#  [165 167 171 ... 101  99  98]
#  [159 161 166 ... 103 102 101]
#  ...
#  [184 185 186 ...  39  38  38]
#  [186 185 185 ...  40  39  38]
#  [186 185 184 ...  41  40  38]]

# %%
plt.imshow(grayimg, cmap = "gray")

# %%
#detecting face
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(grayimg, 1.3, 5)
faces
# Out:
# array([[259, 161, 352, 352]], dtype=int32)

# %%
#face coordinates
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (259, 161, 352, 352)

# %%
#showing face on image
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,0),5)
plt.imshow(face_img)

# %%
#detecting eyes on the face
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,0),5)
    roi_gray = grayimg[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),3)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
#showing cropped face
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
#making function to get above cropped image
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
#checking fucntion
original_image = cv2.imread('./test_images/robert-downey-jr--2.jpg')
plt.imshow(original_image)

# %%
#checking function
cropped_image = get_cropped_image_if_2_eyes('./test_images/robert-downey-jr--2.jpg')
plt.imshow(cropped_image)

# %%
#checking obstructed images
org_image_obstructed = cv2.imread('./test_images/3bfe98880dbdd432dfa3916fb3eabcc1.jpg')
plt.imshow(org_image_obstructed)

# %%
#checking obstructed images
cropped_image_obstructed = get_cropped_image_if_2_eyes('./test_images/3bfe98880dbdd432dfa3916fb3eabcc1.jpg')
cropped_image_obstructed

# %%
#making a cropped folder directory
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
#reading all subfolders
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/Lionel Messi',
#  './dataset/Robert Downey Jr',
#  './dataset/Roger_Fedrer',
#  './dataset/Serena_Williams',
#  './dataset/Virat Kohli']

# %%
#making a cropped folder to make a cropped images dataset to train the moel
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# cropped
# Lionel Messi
# Generating cropped images in folder:  ./dataset/cropped/Lionel Messi
# Robert Downey Jr
# Generating cropped images in folder:  ./dataset/cropped/Robert Downey Jr
# Roger_Fedrer
# Generating cropped images in folder:  ./dataset/cropped/Roger_Fedrer
# Serena_Williams
# Generating cropped images in folder:  ./dataset/cropped/Serena_Williams
# Virat Kohli
# Generating cropped images in folder:  ./dataset/cropped/Virat Kohli
